# %% [markdown]
# Hydromet Python Classes
#
# Intro to Python

# %% [markdown]
# This is a text cell in a Google Colab notebook.

# %%
This is a code cell in a Google Colab notebook. #this will not run as a script.

# %% [markdown]
# Let's write your first program in python.

# %%
print('hello world') #this is a comment about the code. Your first program will print hello world to the screen.
# Out:
# hello world

# %%
help(print) #this command shows you the documentation for the print function
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %% [markdown]
# Data Types: Numbers

# %%
5
# Out:
# 5

# %%
type(5)
# Out:
# int

# %%
3.5
type(3.5)
# Out:
# float

# %%
2 + 3j
type(2 + 3j)
# Out:
# complex

# %% [markdown]
# Python as a calculator

# %%
5 + 3
2 + 4
1000.3435353 - 0.0003434
# Out:
# 1000.3431919

# %% [markdown]
# Try out other operators
# +
# -
# *
# /
# **
# %
# ==
# <
# >
# <=
# >=
# !=
# and
# or
# not
# +=
# -=
# *=
# /=
# %=
# **=
# //=

# %% [markdown]
# We start to reaise that we would like to store variables for later calculations. So we need to declare a variable and python saves that to memory.

# %% [markdown]
# Declaring Variables

# %%
a = 6
type(a)
# Out:
# int

# %%
print(a)
# Out:
# 6

# %%
b = 7.8
type(b)
# Out:
# float

# %%
print(b)
# Out:
# 7.8

# %% [markdown]
# Now we can combine variables and operators to create expressions.

# %%
c = a + b
c #or print(c)
# Out:
# 13.8

# %%
year = 2016
event = 'Referendum'

print()
print('Results of the', year, event)
f'Results of the {year} {event}'
# Out:
# 'Results of the 2016 Referendum'

# %% [markdown]
# Data Types: Strings

# %%
'hello'
# Out:
# 'hello'

# %%
print('Hello')
foo = 'my name is Joe'
print(foo)
# Out:
# Hello
# my name is Joe

# %%
foo = 'what's your name?' #this will cause an error because of the single quote in "what's"
foo = "what's your name?" #this will work because of the double quotes
print(foo)
# Out:
#   File "/tmp/ipython-input-2274941191.py", line 1
#     foo = 'what's your name?' #this will cause an error because of the single quote in "what's"
#                                                                                               ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"""this is a multi-line comment
that spans multiple lines
to explain something about the code below
"""
bar = '''This is a string that uses
triple single quotes to span
multiple lines.'''
print(bar)
# Out:
# This is a string that uses
# triple single quotes to span
# multiple lines.

# %% [markdown]
# Data Structures
#
# Lists - a sequence of items (values). The items in it could belong to any of data type and could be of different data type in the same list.

# %%
a = [1,2,3,4,5] #a list of integers
b = ['one','two','three','four','five'] #a list of strings
c = [1, 'two', 3.0, 'four', 5] #a list with mixed data types      
d = []  #an empty list

# %% [markdown]
# The items in a list are accessed using the indices.
